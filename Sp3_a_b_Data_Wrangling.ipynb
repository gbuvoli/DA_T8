# %% [markdown]
# ![Sprint 3 - Manejo de Datos.pptx (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Sprint 3 - Manejo de Datos.pptx.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Learning Goals
# - Reading and viewing data
# - Missing and duplicated data
# - Data Filtering

# %% [markdown]
# ![Sprint 3 - Manejo de Datos.pptx (2).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Sprint 3 - Manejo de Datos.pptx (3).jpg](data:image/jpeg;base64,...)![Sprint 3 - Manejo de Datos.pptx (4).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Sprint 3 - Manejo de Datos.pptx (5).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [Pandas cheat sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)

# %% [markdown]
# ![Sprint 3 - Manejo de Datos.pptx (6).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Exercises for Live session 1

# %% [markdown]
# Ejercicio 1: Carga el archivo CSV con los datos alterados y muestra las primeras 10 filas del DataFrame.
#
# [Descargar dataset](https://drive.google.com/file/d/1i02tlyRCPzikuC99Jj2m3odvvrhO1AVc/view)

# %%
import pandas as pd
path='https://raw.githubusercontent.com/gbuvoli/Datasets/refs/heads/main/Telco-Customer-Churn-Dirty.csv'

df = pd.read_csv(path)
df
#print(df.head(10))
#print(df.tail(10))
#print(df.shape)
#print(df.columns)
#print(df.sample(5))
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 1     5575-GNVDE    Male            0.0      No        NaN    34.0
# 2            NaN    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7390  2294-DMMUS  Female            NaN     Yes        Yes    62.0
# 7391  5921-NGYRH     NaN            NaN     Yes         No    64.0
# 7392  1897-OKVMW  Female            NaN     Yes        Yes    64.0
# 7393  5117-IFGPS    Male            NaN     Yes         No    29.0
# 7394  3866-MDTUB  Female            NaN      No         No     2.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# Ejercicio 2. Verifica el tipo de datos de cada columna del dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7395 entries, 0 to 7394
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7024 non-null   object
#  1   gender            7023 non-null   object
#  2   SeniorCitizen     6339 non-null   float64
#  3   Partner           7019 non-null   object
#  4   Dependents        7023 non-null   object
#  5   tenure            6653 non-null   float64
#  6   PhoneService      7028 non-null   object
#  7   MultipleLines     7030 non-null   object
#  8   InternetService   7023 non-null   object
#  9   OnlineSecurity    7020 non-null   object
#  10  OnlineBackup      7028 non-null   object
#  11  DeviceProtection  7025 non-null   object
#  12  TechSupport       7014 non-null   object
#  13  StreamingTV       7031 non-null   object
#  14  StreamingMovies   7025 non-null   object
#  15  Contract          7020 non-null   object
# ...

# %% [markdown]
# ### Ejercicio 3: Veamos un análisis estadístico superficial de los datos, según su tipo

# %%
df.describe()
#df.describe(include='object')
#df.describe(include='all')
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    6339.000000  6653.000000     6654.000000
# mean        0.161697    32.434992       64.528314
# std         0.368202    24.555358       30.017678
# min         0.000000     0.000000       18.400000
# 25%         0.000000     9.000000       35.400000
# 50%         0.000000    29.000000       70.200000
# 75%         0.000000    55.000000       89.637500
# max         1.000000    72.000000      118.650000

# %% [markdown]
# Ejercicio 3: Verifica si hay valores ausentes en el conjunto de datos y reemplázalos adecuadamente.

# %%
# Identificar valores ausentes
valores_nulos = df.isna().sum()
print("Valores ausentes en cada columna:\n", valores_nulos)
# Out:
# Valores ausentes en cada columna:
#  customerID           371
# gender               372
# SeniorCitizen       1056
# Partner              376
# Dependents           372
# tenure               742
# PhoneService         367
# MultipleLines        365
# InternetService      372
# OnlineSecurity       375
# OnlineBackup         367
# DeviceProtection     370
# TechSupport          381
# StreamingTV          364
# StreamingMovies      370
# Contract             375
# PaperlessBilling     359
# PaymentMethod        370
# MonthlyCharges       741
# TotalCharges         371
# Churn                378
# dtype: int64

# %%
# Opciones para eliminar filas o columnas con valores ausentes
df.dropna()
df.dropna(axis='columns')
df.dropna(subset=['TotalCharges'])
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 1     5575-GNVDE    Male            0.0      No        NaN    34.0
# 2            NaN    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7390  2294-DMMUS  Female            NaN     Yes        Yes    62.0
# 7391  5921-NGYRH     NaN            NaN     Yes         No    64.0
# 7392  1897-OKVMW  Female            NaN     Yes        Yes    64.0
# 7393  5117-IFGPS    Male            NaN     Yes         No    29.0
# 7394  3866-MDTUB  Female            NaN      No         No     2.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# Rellenar valores ausentes en todas las columnas numéricas con 0 y categoricas con 'unknown'

#df.fillna(0, inplace=True)

df.select_dtypes(include='object').fillna('unknown', inplace=True)
df.select_dtypes(include='number').fillna(0, inplace=True)

# Verificar nuevamente
#print("Valores ausentes después de la limpieza:\n", df.isna().sum())

# %% [markdown]
# Ejercicio 4: Determina si hay filas duplicadas en el conjunto de datos y elimínalas si existen.

# %% [markdown]
# ![Image (1).png](data:image/png;base64,...)

# %%
# Contar duplicados
duplicados = df.duplicated().sum()
print(f"Número de registros duplicados: {duplicados}")

# Eliminar duplicados

df.drop_duplicates(inplace=True)

#df= df.drop_duplicates().reset_index(drop=True)

# Confirmar eliminación
print(f"Número de registros después de eliminar duplicados: {df.duplicated().sum()}")
# Out:
# Número de registros duplicados: 352
# Número de registros después de eliminar duplicados: 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ejercicio 5: Renombra las columnas del DataFrame para que sigan un formato en minúsculas y sin espacios.

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.rename(columns={'online_backup':'OnlineBackup'}, inplace=True)

df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Mostrar nombres de columnas originales
#print("Nombres de columnas originales:", df.columns)

# Renombrar columnas a minúsculas y reemplazar espacios con guiones bajos
# Agrega más columnas según sea necesario, no necesita mostrarlas todas, solamente unos ejemplos
new_names=[]
for column in df.columns:
    new_name = column.lower().replace(" ", "_")
    new_names.append(new_name)

print(new_names)


# Mostrar nombres de columnas modificados
#print("Nombres de columnas normalizados:", df.columns)
# Out:
# ['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents', 'tenure', 'phoneservice', 'multiplelines', 'internetservice', 'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling', 'paymentmethod', 'monthlycharges', 'totalcharges', 'churn']

# %%
df.columns = new_names
df.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %% [markdown]
# Otra forma de hacerlo:

# %%
# Mostrar nombres de columnas originales
print("Nombres de columnas originales:", df.columns)

nuevos_nombres ={
    'customerID': 'customer_id',
    'SeniorCitizen': 'senior_citizen',
    'Partner': 'partner',
    'Dependents': 'dependents',
    'tenure': 'tenure',
    'PhoneService': 'phone_service',
    'MultipleLines': 'multiple_lines',
    'InternetService': 'internet_service',
    'OnlineSecurity': 'online_security',
    'OnlineBackup': 'online_backup',
    'DeviceProtection': 'device_protection',
    'TechSupport': 'tech_support',
    'StreamingTV': 'streaming_tv',
    'StreamingMovies': 'streaming_movies',
    'Contract': 'contract',
    'PaperlessBilling': 'paperless_billing',
    'PaymentMethod': 'payment_method',
    'MonthlyCharges': 'monthly_charges',
    'TotalCharges': 'total_charges',
    'Churn': 'churn'
}

df.rename(columns=nuevos_nombres, inplace=True)

# Mostrar nombres de columnas modificados
print("Nombres de columnas normalizados:", df.columns)
# Out:
# Nombres de columnas originales: Index(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure', 'phone_service', 'multiple_lines', 'internet_service',
#        'online_security', 'OnlineBackup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'contract', 'paperless_billing',
#        'payment_method', 'monthly_charges', 'total_charges', 'churn'],
#       dtype='object')
# Nombres de columnas normalizados: Index(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure', 'phone_service', 'multiple_lines', 'internet_service',
#        'online_security', 'online_backup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'contract', 'paperless_billing',
#        'payment_method', 'monthly_charges', 'total_charges', 'churn'],
#       dtype='object')

# %% [markdown]
# Ejercicio 6: Agrupa los datos por la columna contract y calcula la media de monthlycharges.

# %% [markdown]
# ![Image (2).png](data:image/png;base64,...)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        6691 non-null   object
#  1   gender            6691 non-null   object
#  2   seniorcitizen     6339 non-null   float64
#  3   partner           6691 non-null   object
#  4   dependents        6691 non-null   object
#  5   tenure            6339 non-null   float64
#  6   phoneservice      6691 non-null   object
#  7   multiplelines     6691 non-null   object
#  8   internetservice   6691 non-null   object
#  9   onlinesecurity    6691 non-null   object
#  10  onlinebackup      6691 non-null   object
#  11  deviceprotection  6691 non-null   object
#  12  techsupport       6691 non-null   object
#  13  streamingtv       6691 non-null   object
#  14  streamingmovies   6691 non-null   object
#  15  contract          6691 non-null   object
# ...

# %%
df.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No        NaN    34.0          Yes
# 2         NaN    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       multiplelines internetservice onlinesecurity  ... deviceprotection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['totalcharges'].value_counts()

df['totalcharges']= df['totalcharges'].replace(" ", 0)
df['totalcharges'].value_counts()
# Out:
# totalcharges
# 20.2       11
# 0          11
# 19.75       9
# 19.9        8
# 20.05       8
#            ..
# 197.4       1
# 168.9       1
# 3306.85     1
# 424.75      1
# 1743.9      1
# Name: count, Length: 6215, dtype: int64

# %%
df['totalcharges'] = df['totalcharges'].astype('float')

# %%
# Agrupar por tipo de contrato y calcular la media del cargo mensual
df_agrupado = df.groupby(['contract','internetservice'])['totalcharges'].mean().unstack()
#df_agrupado = df.groupby(['streaming_tv', 'contract'])['monthly_charges'].sum().unstack()

# Mostrar resultados
print("Media del cargo mensual por tipo de contrato:\n", round(df_agrupado,2))
df_agrupado
# Out:
# Media del cargo mensual por tipo de contrato:
#  internetservice      DSL  Fiber optic       No
# contract
# Month-to-month    855.09      1945.13   189.75
# One year         2536.00      5212.84   610.51
# Two year         4222.67      6848.20  1067.75
# internetservice          DSL  Fiber optic           No
# contract
# Month-to-month    855.087000  1945.125164   189.750455
# One year         2535.996300  5212.840198   610.509603
# Two year         4222.668089  6848.204987  1067.746780

# %% [markdown]
# Ejercicio 7: Usa loc para seleccionar información de un cliente específico ('7590-VHVEG') y iloc para obtener los primeros 5 registros del DataFrame.

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure', 'phone_service', 'multiple_lines', 'internet_service',
#        'online_security', 'online_backup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'contract', 'paperless_billing',
#        'payment_method', 'monthly_charges', 'total_charges', 'churn'],
#       dtype='object')

# %%
cliente = df.loc[df['customer_id'] == '7590-VHVEG']
cliente
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  7590-VHVEG  Female             0.0     Yes         No     1.0
#
#   phone_service    multiple_lines internet_service online_security  ...  \
# 0            No  No phone service              DSL              No  ...
#
#   device_protection tech_support streaming_tv streaming_movies  \
# 0                No           No           No               No
#
#          contract paperless_billing payment_method monthly_charges  \
# 0  Month-to-month               Yes            NaN           29.85
#
#    total_charges churn
# 0          29.85    No
#
# [1 rows x 21 columns]

# %%
#df.loc[3:8,'online_backup']
df.loc[3:8,'online_backup':'tech_support']
# Out:
#   online_backup device_protection tech_support
# 3            No               Yes          Yes
# 4            No                No           No
# 5            No               Yes           No
# 6           Yes                No           No
# 7            No                No           No
# 8            No               Yes          Yes

# %%
df.iloc[3:9,10]
df.iloc[3:9,5:10]
# Out:
#    tenure phone_service    multiple_lines internet_service online_security
# 3    45.0            No  No phone service              DSL             Yes
# 4     2.0           Yes                No      Fiber optic              No
# 5     8.0           Yes               Yes      Fiber optic              No
# 6    22.0           Yes               Yes      Fiber optic              No
# 7    10.0            No  No phone service              DSL             Yes
# 8     NaN           Yes               Yes      Fiber optic              No

# %%
#usuarios masculinos que pagan mas de 80 mensuales

cond_1= df['gender']=='Male'
cond_2 = df['monthly_charges']>80

df_filtrado = df[(cond_1) & (cond_2)]

df_filtrado
# Out:
#      customer_id gender  senior_citizen partner dependents  tenure  \
# 6            NaN   Male             0.0      No        Yes    22.0
# 12    8091-TTVAX   Male             0.0     Yes         No    58.0
# 13    0280-XJGEX   Male             0.0      No         No    49.0
# 14    5129-JLPIS   Male             0.0      No         No     NaN
# 17    9959-WOFKT   Male             NaN      No        Yes    71.0
# ...          ...    ...             ...     ...        ...     ...
# 7015  0666-UXTJO   Male             1.0     Yes         No    34.0
# 7022  7203-OYKCT   Male             0.0      No         No    72.0
# 7024  7398-LXGYX   Male             0.0     Yes         No     NaN
# 7038  6840-RESVB   Male             0.0     Yes        Yes    24.0
# 7042  3186-AJIEK   Male             0.0      No         No    66.0
#
#      phone_service multiple_lines internet_service online_security  ...  \
# 6              Yes            Yes      Fiber optic              No  ...
# ...

# %% [markdown]
# Ejercicio 8: Cuenta cuántos valores únicos hay en la columna payment_method.

# %%
# Contar valores únicos en la columna 'payment_method'
unique_payment_methods = df['payment_method'].nunique()
unique_payment_methods_cuales = df['payment_method'].unique()
conteo = df['payment_method'].value_counts()

print(f"Número de métodos de pago únicos: {unique_payment_methods}")
print(f"Detalle de métodos de pago únicos: {unique_payment_methods_cuales}")
print(f"Cuantos de cada uno, métodos de pago únicos: {conteo}")
# Out:
# Número de métodos de pago únicos: 4
# Detalle de métodos de pago únicos: [nan 'Mailed check' 'Bank transfer (automatic)' 'Electronic check'
#  'Credit card (automatic)']
# Cuantos de cada uno, métodos de pago únicos: payment_method
# Electronic check             2249
# Mailed check                 1524
# Bank transfer (automatic)    1460
# Credit card (automatic)      1458
# Name: count, dtype: int64

# %% [markdown]
# Ejercicio 9: Filtra los clientes que tienen un contrato de "Month-to-month" y pagan más de 80 en monthly_charges.

# %%
df[(df['contract']=='Month-to-month') & ( df['monthly_charges'] > 80)]
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 5     9305-CDSKC  Female             0.0      No         No     8.0
# 6              0    Male             0.0      No        Yes    22.0
# 8     7892-POOKP  Female             0.0     Yes         No     0.0
# 13    0280-XJGEX    Male             0.0      No         No    49.0
# 14    5129-JLPIS    Male             0.0      No         No     0.0
# ...          ...     ...             ...     ...        ...     ...
# 7363  4929-XIHVW    Male             0.0     Yes         No     0.0
# 7376  1724-BQUHA    Male             0.0      No         No     5.0
# 7379  3898-GUYTS       0             0.0      No         No    45.0
# 7381  9779-DPNEJ  Female             0.0     Yes        Yes     0.0
# 7393  5117-IFGPS    Male             0.0     Yes         No    29.0
#
#      phone_service multiple_lines internet_service online_security  ...  \
# 5              Yes            Yes      Fiber optic              No  ...
# ...

# %%
filtered_df = df.query("contract == 'Month-to-month' and monthly_charges > 80")
filtered_df
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 5     9305-CDSKC  Female             0.0      No         No     8.0
# 6            NaN    Male             0.0      No        Yes    22.0
# 8     7892-POOKP  Female             0.0     Yes         No     NaN
# 13    0280-XJGEX    Male             0.0      No         No    49.0
# 14    5129-JLPIS    Male             0.0      No         No     NaN
# ...          ...     ...             ...     ...        ...     ...
# 7014  9053-EJUNL    Male             0.0      No         No    41.0
# 7015  0666-UXTJO    Male             1.0     Yes         No    34.0
# 7024  7398-LXGYX    Male             0.0     Yes         No     NaN
# 7025  2823-LKABH  Female             0.0      No         No    18.0
# 7034  0639-TSIQW  Female             NaN     NaN         No    67.0
#
#      phone_service multiple_lines internet_service online_security  ...  \
# 5              Yes            Yes      Fiber optic              No  ...
# ...

# %% [markdown]
# Ejercicio 10: Usa query() para encontrar los clientes que tienen servicio de internet de tipo "Fiber optic" y no tienen seguridad en línea.

# %%
# Filtrar clientes con 'Fiber optic' en InternetService y sin 'OnlineSecurity'
filtered_query = df.query("internet_service == 'Fiber optic' and online_security == 'No'")

# Mostrar las primeras filas del resultado
filtered_query.head()
# Out:
#    customer_id  gender  senior_citizen partner dependents  tenure  \
# 4   9237-HQITU  Female             0.0      No         No     2.0
# 5   9305-CDSKC  Female             0.0      No         No     8.0
# 6          NaN    Male             0.0      No        Yes    22.0
# 8   7892-POOKP  Female             0.0     Yes         No     NaN
# 12  8091-TTVAX    Male             0.0     Yes         No    58.0
#
#    phone_service multiple_lines internet_service online_security  ...  \
# 4            Yes             No      Fiber optic              No  ...
# 5            Yes            Yes      Fiber optic              No  ...
# 6            Yes            Yes      Fiber optic              No  ...
# 8            Yes            Yes      Fiber optic              No  ...
# 12           Yes            Yes      Fiber optic              No  ...
#
#    device_protection tech_support streaming_tv streaming_movies  \
# 4                 No           No           No               No
# ...

# %%
filtered_mask =df[(df['internet_service']=='Fiber optic') & (df['online_security']=='No')]
filtered_mask.head()
# Out:
#    customer_id  gender  senior_citizen partner dependents  tenure  \
# 4   9237-HQITU  Female             0.0      No         No     2.0
# 5   9305-CDSKC  Female             0.0      No         No     8.0
# 6          NaN    Male             0.0      No        Yes    22.0
# 8   7892-POOKP  Female             0.0     Yes         No     NaN
# 12  8091-TTVAX    Male             0.0     Yes         No    58.0
#
#    phone_service multiple_lines internet_service online_security  ...  \
# 4            Yes             No      Fiber optic              No  ...
# 5            Yes            Yes      Fiber optic              No  ...
# 6            Yes            Yes      Fiber optic              No  ...
# 8            Yes            Yes      Fiber optic              No  ...
# 12           Yes            Yes      Fiber optic              No  ...
#
#    device_protection tech_support streaming_tv streaming_movies  \
# 4                 No           No           No               No
# ...

# %% [markdown]
# Ejercicio 11:  Agrupa los datos por contract y calcula la cantidad de clientes en cada tipo de contrato.

# %%
# Agrupar por tipo de contrato y contar la cantidad de clientes en cada categoría
contract_counts=df.groupby('contract')['customer_id'].count()

# Mostrar el resultado
print("Cantidad de clientes por tipo de contrato:\n", contract_counts)
# Out:
# Cantidad de clientes por tipo de contrato:
#  contract
# Month-to-month    3492
# One year          1318
# Two year          1551
# Name: customer_id, dtype: int64

# %%
df['contract'].value_counts()
# Out:
# contract
# Month-to-month    3670
# Two year          1627
# One year          1394
# Name: count, dtype: int64

# %% [markdown]
# # AHORA YA SABES:
# --
# 1. Cargar un Dataset
# 2. Explorar sus características
# 3. Identificar, reemplazar y eliminar datos Nulos o duplicados
# 4. Ajustar nombres de las columnas
# 5. Agrupar y agregar datos.
# 6. Indexar y segmentar un dataser (iloc, loc)
# 7. Filtrar datasets utilizando .loc o querys

# %% [markdown]
# ![Sprint 3 - Manejo de Datos.pptx.png](data:image/png;base64,...)![Sprint 3 - Manejo de Datos.pptx (7).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # ¿Como te sientes para afrontar el proyecto del Sprint 3?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Sprint 3 - Manejo de Datos.pptx (8).jpg](data:image/jpeg;base64,...)
